# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# *Python is case sencitive language*

# %%
a =2
type(a)
# Out:
# int

# %% [markdown]
# ***that means "a" and "A" are different things***

# %%
print("Hey",10,2.2,'Hello')
# Out:
# Hey 10 2.2 Hello
